# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cd ..
# Out:
# /Users/arnau/Documents/physics/codes/nnsc

# %%
# %matplotlib inline

# %%
run main.py save False n_test 1000 n_train 1000 n_epochs 100 version deep_reg_est selection original
# Out:
#             _  _
#           /u@)(@\        running bias_ldae.py
#      nn      Y
#      ' Y_____H____
#       \ V  |-['']-|___,,
#        \ \ |T'T' T|___nn
#        |   || |  ||   UU
#        /``\WALL.E `\
#       / /A \   / A  \
#       L____J   L____J
#
# Learn the network
#
#
#
# Fully supervised learning
#
#
#
# | Mean Sq error |   Epoch  |
# |---------------|----------|
# |     0.722427  |    0   |
# |     0.714125  |    1   |
# |     0.705809  |    2   |
# |     0.697345  |    3   |
# |     0.688812  |    4   |
# |     0.680506  |    5   |
# |     0.672530  |    6   |
# |     0.664854  |    7   |
# |     0.657464  |    8   |
# |     0.650302  |    9   |
# |     0.643167  |    10   |
# |     0.635867  |    11   |
# |     0.628530  |    12   |
# |     0.621332  |    13   |
# |     0.614313  |    14   |
# |     0.607547  |    15   |
# |     0.601005  |    16   |
# |     0.594667  |    17   |
# |     0.588518  |    18   |
# |     0.582531  |    19   |
# ...

# %%
yvar.shape
# Out:
# (1935307,)

# %%
galsim_props
# Out:
# ['g1',
#  'g2',
#  'bulge_n',
#  'bulge_hlr',
#  'bulge_q',
#  'bulge_beta_radians',
#  'bulge_flux',
#  'disk_hlr',
#  'disk_q',
#  'disk_beta_radians',
#  'disk_flux',
#  'gal_sn',
#  'g1_intrinsic',
#  'g2_intrinsic',
#  'psf_theta',
#  'in_beta',
#  'in_q',
#  'gp',
#  'gx',
#  'gp_intrinsic',
#  'gx_intrinsic']

# %%
input_props
# Out:
# ['gFIT_final_e1',
#  'gFIT_final_e2',
#  'gFIT_out_flux',
#  'gFIT_out_e1',
#  'gFIT_out_e2',
#  'gFIT_out_gal_sigma_noise',
#  'gFIT_out_dre',
#  'gFIT_out_bre',
#  'gFIT_out_df',
#  'gFIT_out_nb_fev',
#  'gFIT_SE_GAL_FLUX',
#  'gFIT_SE_GAL_FLUX_RADIUS',
#  'gFIT_SE_GAL_SNR',
#  'gFIT_SE_GAL_MAG',
#  'gFIT_SE_PSF_FLUX',
#  'gFIT_SE_PSF_FLUX_RADIUS',
#  'gFIT_SE_PSF_SNR',
#  'gFIT_SE_PSF_MAG',
#  'gFIT_SE_PSF_FWHM_IMAGE',
#  'gFIT_out_beta',
#  'gFIT_out_q',
#  'KSB_final_e1',
#  'KSB_final_e2',
#  'KSB_out_scale',
#  'KSB_out_sn',
#  'KSB_out_beta',
#  'KSB_out_q',
#  'KSB_final_ep',
#  'KSB_final_ex']
