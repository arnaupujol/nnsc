# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cd ..
# Out:
# /Users/arnau/Documents/physics/codes/nnsc

# %%
# %matplotlib inline

# %%
run main.py save False n_test 6000 n_train 6000 n_epochs 100 version deep_reg_est selection original show True
# Out:
#             _  _
#           /u@)(@\        running bias_ldae.py
#      nn      Y
#      ' Y_____H____
#       \ V  |-['']-|___,,
#        \ \ |T'T' T|___nn
#        |   || |  ||   UU
#        /``\WALL.E `\
#       / /A \   / A  \
#       L____J   L____J
#
# Learn the network
#
#
#
# Fully supervised learning
#
#
#
# | Mean Sq error |   Epoch  |
# |---------------|----------|
# |     0.882953  |    0   |
# |     0.851635  |    1   |
# |     0.815852  |    2   |
# |     0.763124  |    3   |
# |     0.718284  |    4   |
# |     0.677777  |    5   |
# |     0.639185  |    6   |
# |     0.602734  |    7   |
# |     0.566843  |    8   |
# |     0.529929  |    9   |
# |     0.486502  |    10   |
# |     0.448517  |    11   |
# |     0.416632  |    12   |
# |     0.389658  |    13   |
# |     0.366800  |    14   |
# |     0.347706  |    15   |
# |     0.331541  |    16   |
# |     0.318758  |    17   |
# |     0.308845  |    18   |
# |     0.300934  |    19   |
# ...
