# %% [markdown]
# # Paper example of NNSC run

# %%
cd ..
# Out:
# /Users/arnau/Documents/physics/codes/nnsc

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This is the training parameterization used for the fiducial model of Pujol et al. (2020) (although with a smaller data set so that we do not need to get the same performance)

# %%
run run_nnsc.py n_train 128000 n_test 128000 n_epochs 6000 batch_size 32 learning_rate 0.0001
# Out:
#             _  _
#           /u@)(@\        running bias_ldae.py
#      nn      Y
#      ' Y_____H____
#       \ V  |-['']-|___,,
#        \ \ |T'T' T|___nn
#        |   || |  ||   UU
#        /``\WALL.E `\
#       / /A \   / A  \
#       L____J   L____J
#
# Learn the network
#
#
#
# Fully supervised learning
#
#
#
# | Mean Sq error |   Epoch  |
# |---------------|----------|
# |     0.026002  |    0   |
# |     0.024488  |    1   |
# |     0.023095  |    2   |
# |     0.022437  |    3   |
# |     0.022093  |    4   |
# |     0.021858  |    5   |
# |     0.021592  |    6   |
# |     0.021196  |    7   |
# |     0.020579  |    8   |
# |     0.020080  |    9   |
# |     0.019776  |    10   |
# |     0.019540  |    11   |
# |     0.019384  |    12   |
# |     0.019277  |    13   |
# |     0.019190  |    14   |
# |     0.019102  |    15   |
# |     0.019045  |    16   |
# |     0.019003  |    17   |
# |     0.018963  |    18   |
# |     0.018880  |    19   |
# ...
